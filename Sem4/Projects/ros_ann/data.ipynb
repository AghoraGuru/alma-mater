# %%
import pandas as pd
path = '/home/kalyan/Desktop/datasetIRB2400.csv'

# Read the data
data = pd.read_csv(path)
data.head(1000)
# Out:
#            x         y          z     yaw   pitch    roll   q1_in   q2_in  \
# 0   -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.2407 -0.7975
# 1   -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.2233 -0.8511
# 2   -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.2567 -0.9468
# 3   -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.1557 -0.8205
# 4   -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.3267 -0.9279
# ..       ...       ...        ...     ...     ...     ...     ...     ...
# 995 -73.9893 -199.3347  1784.3901  3.0938  0.1018 -0.8274  1.1058 -0.9931
# 996 -73.9893 -199.3347  1784.3901  3.0938  0.1018 -0.8274  1.0347 -1.0182
# 997 -73.9893 -199.3347  1784.3901  3.0938  0.1018 -0.8274  1.1458 -0.9821
# 998 -73.9893 -199.3347  1784.3901  3.0938  0.1018 -0.8274  1.1735 -0.9190
# 999 -73.9893 -199.3347  1784.3901  3.0938  0.1018 -0.8274  1.1044 -0.9590
#
#       q3_in   q4_in   q5_in   q6_in  q1_out  q2_out  q3_out  q4_out  q5_out  \
# ...

# %%
#chek for null values
data.isnull().sum()
# Out:
# x         0
# y         0
# z         0
# yaw       0
# pitch     0
# roll      0
# q1_in     0
# q2_in     0
# q3_in     0
# q4_in     0
# q5_in     0
# q6_in     0
# q1_out    0
# q2_out    0
# q3_out    0
# q4_out    0
# q5_out    0
# q6_out    0
# dtype: int64
