# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import cv2
import imageio as iio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 import numpy as np
#       5 from PIL import Image
# ----> 6 import cv2
#       7 import imageio as iio
#
# ModuleNotFoundError: No module named 'cv2'

# %%
data_path = "/home/kalyan/DataSets/YalFaceDataSet/data/"

# %%
# Imports
from matplotlib import pyplot as plta
import numpy as np

filename = "/home/kalyan/DataSets/YaleFaceDataSet/subject01.centerlight"
pixels = plta.imread(filename)

rgb_pixels = np.stack(( pixels, pixels))
plta.imshow(pixels,cmap='gray')
plta.show()

N = rgb_pixels.shape[0]
for k in range(N):
    print(k)
# Out:
# 0
# 1

# %%
def DFT(input):
    N = input.shape[0] 
    output = np.zeros(input.shape, dtype=complex)
    B = np.zeros(input.shape, dtype=complex)
    for k in range(N): #here k is the frequency
        for n in range(N): #here n is the time
            B[n] = np.exp(-1j*2*np.pi*k*n/N) 
        output[k] = np.sum(input*B)
    return output

# %%
#setting labesl for the images based on file names
def get_labels(path):
    labels = []
    for dirname, _, filenames in os.walk(path):
        for filename in filenames:
            labels.append(filename.split(".")[0])
    return labels

labels = get_labels(data_path)
print(labels)
#Label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
labels = le.fit_transform(labels)
print((labels))
# Out:
# ['subject09', 'subject12', 'subject15', 'subject14', 'subject03', 'subject06', 'subject07', 'subject09', 'subject02', 'subject14', 'subject06', 'subject03', 'subject10', 'subject02', 'subject03', 'subject02', 'subject05', 'subject10', 'subject14', 'subject07', 'subject09', 'subject11', 'subject07', 'subject04', 'subject11', 'subject11', 'subject05', 'subject11', 'subject03', 'subject03', 'subject13', 'subject15', 'subject11', 'subject10', 'subject03', 'subject15', 'subject02', 'subject05', 'subject13', 'subject09', 'subject14', 'subject10', 'subject09', 'subject08', 'subject07', 'subject07', 'subject01', 'subject01', 'subject12', 'subject12', 'subject12', 'subject12', 'subject07', 'subject04', 'subject01', 'subject12', 'subject02', 'subject01', 'subject04', 'subject06', 'subject03', 'subject15', 'subject06', 'subject02', 'subject08', 'subject09', 'subject02', 'subject08', 'subject15', 'subject01', 'subject06', 'subject06', 'subject10', 'subject11', 'subject15', 'subject14', 'subject06', 'subject06', 'subject02', 'subject02', 'subject08', 'subject07', 'subject14', 'subject04', 'subject05', 'subject03', 'subject04', 'subject15', 'subject13', 'subject04', 'subject01', 'subject11', 'subject01', 'subject01', 'subject12', 'subject05', 'subject08', 'subject12', 'subject06', 'subject05', 'subject15', 'subject08', 'subject12', 'subject15', 'subject02', 'subject10', 'subject07', 'subject02', 'subject05', 'subject11', 'subject04', 'subject04', 'subject12', 'subject01', 'subject13', 'subject14', 'subject05', 'subject12', 'subject01', 'subject10', 'subject09', 'subject03', 'subject13', 'subject13', 'subject11', 'subject10', 'subject03', 'subject04', 'subject05', 'subject13', 'subject14', 'subject09', 'subject10', 'subject06', 'subject09', 'subject13', 'subject14', 'subject07', 'subject08', 'subject04', 'subject07', 'subject08', 'subject09', 'subject06', 'subject05', 'subject11', 'subject11', 'subject08', 'subject01', 'subject10', 'subject15', 'subject13', 'subject09', 'subject08', 'subject10', 'subject13', 'subject07', 'subject15', 'subject14', 'subject08', 'subject03', 'subject05', 'subject13', 'subject14', 'subject04']
# [ 8 11 14 13  2  5  6  8  1 13  5  2  9  1  2  1  4  9 13  6  8 10  6  3
#  10 10  4 10  2  2 12 14 10  9  2 14  1  4 12  8 13  9  8  7  6  6  0  0
#  11 11 11 11  6  3  0 11  1  0  3  5  2 14  5  1  7  8  1  7 14  0  5  5
#   9 10 14 13  5  5  1  1  7  6 13  3  4  2  3 14 12  3  0 10  0  0 11  4
#   7 11  5  4 14  7 11 14  1  9  6  1  4 10  3  3 11  0 12 13  4 11  0  9
#   8  2 12 12 10  9  2  3  4 12 13  8  9  5  8 12 13  6  7  3  6  7  8  5
#   4 10 10  7  0  9 14 12  8  7  9 12  6 14 13  7  2  4 12 13  3]

# %%
def read_image(path):
    pixels = plta.imread(path)
    rgb_pixels = np.stack((pixels, pixels, pixels), axis=2)
    return rgb_pixels

images = []
for dirname, _, filenames in os.walk(data_path):
    for filename in filenames:
        images.append(os.path.join(dirname, filename))

print(len(images))
# Out:
# 165

# %%
dft_images = []
for image in images:
    dft_images.append(DFT(read_image(image)))

# %%
dft_images = np.array(dft_images)

# %%
#flatten the images
dft_images = dft_images.reshape(dft_images.shape[0], -1)

# %%
dft_images.shape
# Out:
# (165, 233280)

# %%
dft_images = np.real(dft_images)

# %%
#getting eigen vectors
def get_eigen_vectors(data):
    mean = np.mean(data, axis=0)
    data = data - mean
    cov = np.cov(data)
    eigen_values, eigen_vectors = np.linalg.eig(cov)
    return eigen_values, eigen_vectors

eigen_values, eigen_vectors = get_eigen_vectors(dft_images)

# %%
eigen_values.shape
# Out:
# (165,)

# %%
#doing pca on the eigen vectors
def pca(eigen_vectors, eigen_values, n_components):
    eigen_vectors = eigen_vectors[:, :n_components]
    eigen_values = eigen_values[:n_components]
    return eigen_vectors, eigen_values

n_components = 150
eigen_vectors, eigen_values = pca(eigen_vectors, eigen_values, n_components)

# %%
eigen_vectors =  np.real(eigen_vectors) #taking only real part of the eigen vectors

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from lazypredict.Supervised import LazyClassifier

# %%
X_trian, X_test, y_train, y_test = train_test_split(eigen_vectors, labels, test_size=0.2, random_state=42)

# %%
clf =  LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_trian, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 14.10it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.91               0.89    None      0.92
# RandomForestClassifier             0.85               0.85    None      0.87
# LinearDiscriminantAnalysis         0.85               0.82    None      0.86
# NuSVC                              0.79               0.81    None      0.86
# RidgeClassifier                    0.82               0.80    None      0.81
# RidgeClassifierCV                  0.82               0.80    None      0.82
# LGBMClassifier                     0.79               0.77    None      0.78
# LogisticRegression                 0.79               0.76    None      0.80
# PassiveAggressiveClassifier        0.79               0.75    None      0.78
# SVC                                0.70               0.74    None      0.78
# NearestCentroid                    0.73               0.71    None      0.75
# BernoulliNB                        0.73               0.70    None      0.72
# CalibratedClassifierCV             0.73               0.70    None      0.72
# Perceptron                         0.73               0.70    None      0.75
# GaussianNB                         0.67               0.69    None      0.70
# XGBClassifier                      0.73               0.69    None      0.70
# SGDClassifier                      0.70               0.68    None      0.73
# LinearSVC                          0.70               0.66    None      0.69
# DecisionTreeClassifier             0.58               0.58    None      0.59
# KNeighborsClassifier               0.58               0.54    None      0.54
# BaggingClassifier                  0.55               0.54    None      0.53
# ExtraTreeClassifier                0.36               0.40    None      0.36
# LabelSpreading                     0.45               0.39    None      0.53
# LabelPropagation                   0.45               0.39    None      0.53
# QuadraticDiscriminantAnalysis      0.12               0.16    None      0.14
# AdaBoostClassifier                 0.06               0.07    None      0.05
# DummyClassifier                    0.00               0.00    None      0.00
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.10
# RandomForestClassifier               0.14
# LinearDiscriminantAnalysis           0.06
# NuSVC                                0.01
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.02
# LGBMClassifier                       0.51
# LogisticRegression                   0.01
# PassiveAggressiveClassifier          0.02
# SVC                                  0.03
# NearestCentroid                      0.01
# BernoulliNB                          0.01
# CalibratedClassifierCV               0.23
# Perceptron                           0.01
# GaussianNB                           0.01
# XGBClassifier                        0.39
# SGDClassifier                        0.04
# LinearSVC                            0.11
# DecisionTreeClassifier               0.01
# KNeighborsClassifier                 0.03
# BaggingClassifier                    0.05
# ExtraTreeClassifier                  0.01
# LabelSpreading                       0.02
# LabelPropagation                     0.04
# QuadraticDiscriminantAnalysis        0.01
# AdaBoostClassifier                   0.14
# DummyClassifier                      0.01

# %%
#saving results to csv
models.to_csv("results.csv")
